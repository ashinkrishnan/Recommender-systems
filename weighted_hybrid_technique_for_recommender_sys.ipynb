# %%
import pandas as pd
import numpy as np

# %%
df_cr = pd.read_csv(r'C:\Users\MYPC\Desktop\Data_sets\tmdb_5000\tmdb_5000_credits.csv')
df_mov= pd.read_csv(r'C:\Users\MYPC\Desktop\Data_sets\tmdb_5000\tmdb_5000_movies.csv')

# %%
df_cr.shape,df_mov.shape
# Out:
# ((4803, 4), (4803, 20))

# %%
df_cr.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df_mov.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df_cr.new = df_cr.rename(index=str,columns={'movie_id':'id'})
df_movies = df_mov.merge(df_cr.new,on='id')
# Out:
# <ipython-input-57-32e08a5b3e34>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_cr.new = df_cr.rename(index=str,columns={'movie_id':'id'})

# %%
df_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df = df_movies.drop(columns=['homepage', 'title_x', 'title_y', 'status','production_countries'])
df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   id                    4803 non-null   int64
#  3   keywords              4803 non-null   object
#  4   original_language     4803 non-null   object
#  5   original_title        4803 non-null   object
#  6   overview              4800 non-null   object
#  7   popularity            4803 non-null   float64
#  8   production_companies  4803 non-null   object
#  9   release_date          4802 non-null   object
#  10  revenue               4803 non-null   int64
#  11  runtime               4801 non-null   float64
#  12  spoken_languages      4803 non-null   object
#  13  tagline               3959 non-null   object
#  14  vote_average          4803 non-null   float64
# ...

# %%
#average rating for the movie
R = df['vote_average']

#no of vote for the movie
V = df['vote_count']

#mean vote across the whole report
C = df['vote_average'].mean()

#minimum vote required
M = df['vote_count'].quantile(0.70)

# %%
df['weighted_avg'] = ((R*V)+(C*M))/(V+M)

# %%
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
#sort dataframe on the basis of weighted_avg

df_sorted = df.sort_values('weighted_avg',ascending=False)
df_sorted[['original_title','popularity','vote_average','weighted_avg']].head()
# Out:
#                 original_title  popularity  vote_average  weighted_avg
# 1881  The Shawshank Redemption  136.747729           8.5      8.340775
# 3337             The Godfather  143.659698           8.4      8.192887
# 662                 Fight Club  146.757391           8.3      8.171648
# 3232              Pulp Fiction  121.463076           8.3      8.157615
# 65             The Dark Knight  187.322927           8.2      8.102674

# %%
#sort dataframe on the basis of popularity

df_popularity = df.sort_values('popularity',ascending=False)
df_popularity[['original_title','popularity','vote_average','weighted_avg']].head()
# Out:
#               original_title  popularity  vote_average  weighted_avg
# 546                  Minions  875.581305           6.4      6.365286
# 95              Interstellar  724.247784           8.1      7.998100
# 788                 Deadpool  514.569956           7.4      7.334360
# 94   Guardians of the Galaxy  481.098624           7.9      7.798252
# 127       Mad Max: Fury Road  434.278564           7.2      7.135687

# %%
#recommendation on the basis of both popularity and weighted avg

from sklearn.preprocessing import MinMaxScaler

scalaing = MinMaxScaler()
scaled_df= scalaing.fit_transform(df[['popularity','weighted_avg']])

df_normalized = pd.DataFrame(scaled_df,columns=['popularity','weighted_avg'])

# %%
df_normalized.head()
# Out:
#    popularity  weighted_avg
# 0    0.171815      0.674339
# 1    0.158846      0.581403
# 2    0.122635      0.436273
# 3    0.128272      0.773054
# 4    0.050169      0.387739

# %%
df[['popularity_normalized','weighted_avg_normalized']] = df_normalized

# %%
df.head(1)
# Out:
#       budget                                             genres     id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies release_date  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...   2009-12-10
#
#    ...  runtime                                   spoken_languages  \
# 0  ...    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#                        tagline vote_average  vote_count  \
# 0  Enter the World of Pandora.          7.2       11800
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
# ...

# %%
df['score'] = df['popularity_normalized']*0.5 + df['weighted_avg_normalized']*0.5
df_score    = df.sort_values(['score'],ascending=False)
df_score[['original_title','popularity_normalized','weighted_avg_normalized','score']]
# Out:
#                original_title  popularity_normalized  weighted_avg_normalized  \
# 95               Interstellar               0.827162                 0.906439
# 546                   Minions               1.000000                 0.460630
# 94    Guardians of the Galaxy               0.549462                 0.851874
# 788                  Deadpool               0.587690                 0.725217
# 127        Mad Max: Fury Road               0.495989                 0.670973
# ...                       ...                    ...                      ...
# 2122               Epic Movie               0.006926                 0.102239
# 210            Batman & Robin               0.057189                 0.019593
# 3746        The Boy Next Door               0.027595                 0.039279
# 242            Fantastic Four               0.043544                 0.017935
# 1652     Dragonball Evolution               0.024758                 0.000000
#
#          score
# 95    0.866801
# ...
